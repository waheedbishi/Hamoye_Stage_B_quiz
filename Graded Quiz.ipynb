# %%
#importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#importing data

df = pd.read_csv('energydata_complete.csv', parse_dates=['date']) #import dataset and change date column datatype to date

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  datetime64[ns]
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.isnull().sum()#No null values
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.set_index('date', inplace = True)  #Set date column as index

# %%
df.head(5)
# Out:
#                      Appliances  lights     T1       RH_1    T2       RH_2  \
# date
# 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#                         T3       RH_3         T4       RH_4  ...         T9  \
# date                                                         ...
# 2016-01-11 17:00:00  19.79  44.730000  19.000000  45.566667  ...  17.033333
# 2016-01-11 17:10:00  19.79  44.790000  19.000000  45.992500  ...  17.066667
# 2016-01-11 17:20:00  19.79  44.933333  18.926667  45.890000  ...  17.000000
# 2016-01-11 17:30:00  19.79  45.000000  18.890000  45.723333  ...  17.000000
# ...

# %%
df.describe() #Descriptive Statistics
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
pd.DataFrame.hist(df, figsize = [15,15]); #Distribution of each column of data

# %% [markdown]
# We observe that while some columns like T1, T4 & Tdewpoint have data normally distributed, most columns have data which are not normally distributed

# %% [markdown]
# ### Instructions
#
# To answer some questions, you will need to normalize the dataset using the MinMaxScaler after removing the following columns: [“date”, “lights”]. The target variable is “Appliances”. Use a 70-30 train-test set split with a random state of 42 (for reproducibility). Run a multiple linear regression using the training set and evaluate your model on the test set.

# %% [markdown]
# Date column has already been converted to the index.
#
# We shall drop the lights column, then proceed with multiple linear regression after normalizing the dataset.

# %%
df.drop('lights', axis = 1, inplace = True) #Dropped Light column from dataset

# %%
df.head()
# Out:
#                      Appliances     T1       RH_1    T2       RH_2     T3  \
# date
# 2016-01-11 17:00:00          60  19.89  47.596667  19.2  44.790000  19.79
# 2016-01-11 17:10:00          60  19.89  46.693333  19.2  44.722500  19.79
# 2016-01-11 17:20:00          50  19.89  46.300000  19.2  44.626667  19.79
# 2016-01-11 17:30:00          50  19.89  46.066667  19.2  44.590000  19.79
# 2016-01-11 17:40:00          60  19.89  46.333333  19.2  44.530000  19.79
#
#                           RH_3         T4       RH_4         T5  ...  \
# date                                                             ...
# 2016-01-11 17:00:00  44.730000  19.000000  45.566667  17.166667  ...
# 2016-01-11 17:10:00  44.790000  19.000000  45.992500  17.166667  ...
# 2016-01-11 17:20:00  44.933333  18.926667  45.890000  17.166667  ...
# 2016-01-11 17:30:00  45.000000  18.890000  45.723333  17.166667  ...
# 2016-01-11 17:40:00  45.000000  18.890000  45.530000  17.200000  ...
#
# ...

# %%
X = df['T2']#input or independent variables

# %%
X = X.to_numpy()

# %%
X = X.reshape(-1, 1)

# %%
y = df['T6']

# %%
y = y.to_numpy()

# %%
y = y.reshape(-1, 1)

# %%
# create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#scaler = MinMaxScaler()

# %%
#X_train_scaled = scaler.fit_transform(X_train)

# %%
lr1 = LinearRegression()

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print ("Intercept for our simple linear regression is: ", lr1.intercept_)
print ("Coefficient for our simple linear regression is: ",lr1.coef_)
# Out:
# Intercept for our simple linear regression is:  [-37.36585299]
# Coefficient for our simple linear regression is:  [[2.22531769]]

# %%
y_pred = lr1.predict(X_test) #Predict y_values (Global Active Power) using the test data.

# %%
print('Simple regression model R Squared score is', lr1.score(X_train, y_train))
# Out:
# Simple regression model R Squared score is 0.6415148739809167

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 13.17918794078674

# %%
#model = lm.fit(X_train_scaled, y_train)

# %%
#X_test_scaled = scaler.transform(X_test)

# %%
#y_pred = lm.predict(X_test_scaled)

# %%
#plt.scatter(y_test, y_pred)
#plt.xlabel("True values")
#plt.ylabel("Predictions")

# %%
#model.score(X_test, y_test)
